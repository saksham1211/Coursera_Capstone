# %% [markdown]
# ## The Battle of Neighborhood
# ### Introduction
# This project is to take a glimpse at different neighborhoods of Bangalore
# Travelers from inside and outside of New England area who want to dicide where to visit and business owners may be interested in the project.
# ### Data
# I organized two data sets of zipcode and neighborhoods with latitude and longtude for each city from multiple online sources
# ### Methodology
# Basic skills from week 3 lab
# Majorly relied on Foursquare API to retrieve all venues of each neighborhoods, then group by each neighborhoods and to count how many venues before filter top 10 most common venue types of each neighborhoods

# %%
import pandas as pd

# %%
df=pd.read_csv('all_india_PO_list_without_APS_offices_ver2_lat_long.csv')
df
# Out:
#                        officename  pincode  ... longitude latitude
# 0                   Achalapur B.O   504273  ...       NaN      NaN
# 1                         Ada B.O   504293  ...       NaN      NaN
# 2                     Adegaon B.O   504307  ...       NaN      NaN
# 3       Adilabad Collectorate S.O   504001  ...       NaN      NaN
# 4                    Adilabad H.O   504001  ...       NaN      NaN
# ...                           ...      ...  ...       ...      ...
# 154792       Uttar Sautanchak B.O   721649  ...       NaN      NaN
# 154793            Uttarjianda B.O   721151  ...       NaN      NaN
# 154794          Uttarkotebarh B.O   721626  ...       NaN      NaN
# 154795         Uttarmechogram B.O   721139  ...       NaN      NaN
# 154796           Uttarsonamui B.O   721648  ...       NaN      NaN
#
# [154797 rows x 15 columns]

# %%
df1=df.dropna(subset=['latitude','longitude']) 
df1
# Out:
#                              officename  pincode  ... longitude latitude
# 5154                 Prakashamnagar S.O   500016  ...   78.4468  17.4672
# 52180                Arabic College S.O   560045  ...   77.6206  13.0291
# 52187                     Bellandur S.O   560103  ...   77.6760  12.9298
# 52201                        Domlur S.O   560071  ...   77.6359  12.9611
# 52204   Dr. Shivarama Karanth Nagar S.O   560077  ...   77.6293  13.0681
# ...                                 ...      ...  ...       ...      ...
# 60131                  T Narasipura S.O   571124  ...   76.8978  12.2151
# 60132                       Tagadur S.O   571119  ...   76.8089  12.0965
# 60133                       Talakad S.O   571122  ...   77.0259  12.1922
# 60136                  Thandavapura S.O   571302  ...   76.6754  12.1693
# 124929                 Variyankaval S.O   621806  ...   78.4475  17.4718
#
# [142 rows x 15 columns]

# %%
df2=df1.drop(['Deliverystatus','officeType','Related Suboffice','Related Headoffice','circlename','Taluk','Telephone','regionname','statename'], axis=1)
df2.head()
# Out:
#                             officename  pincode  ... longitude latitude
# 5154                Prakashamnagar S.O   500016  ...   78.4468  17.4672
# 52180               Arabic College S.O   560045  ...   77.6206  13.0291
# 52187                    Bellandur S.O   560103  ...   77.6760  12.9298
# 52201                       Domlur S.O   560071  ...   77.6359  12.9611
# 52204  Dr. Shivarama Karanth Nagar S.O   560077  ...   77.6293  13.0681
#
# [5 rows x 6 columns]

# %%
df3 = df2[df2['Districtname'].str.contains('Bangalore')].reset_index(drop=True)
df3
# Out:
#                            officename  pincode  ... longitude latitude
# 0                  Arabic College S.O   560045  ...   77.6206  13.0291
# 1                       Bellandur S.O   560103  ...   77.6760  12.9298
# 2                          Domlur S.O   560071  ...   77.6359  12.9611
# 3     Dr. Shivarama Karanth Nagar S.O   560077  ...   77.6293  13.0681
# 4                     Fraser Town S.O   560005  ...   77.6164  13.0005
# 5                        G.K.V.K. S.O   560065  ...   77.5784  13.0781
# 6                  H.A.L II Stage H.O   560008  ...   77.6427  12.9686
# 7                       HighCourt S.O   560001  ...   77.5915  12.9773
# 8                Jeevanbhimanagar S.O   560075  ...   77.6535  12.9695
# 9                        Kothanur S.O   560077  ...   77.6478  13.0614
# 10            Mahatma Gandhi Road S.O   560001  ...   77.6100  12.9739
# 11            Marathahalli Colony S.O   560037  ...   77.6880  12.9559
# ...

# %%
df4=df3.drop(['Districtname'], axis=1)
df4.head()
# Out:
#                         officename  pincode  ... longitude  latitude
# 0               Arabic College S.O   560045  ...   77.6206   13.0291
# 1                    Bellandur S.O   560103  ...   77.6760   12.9298
# 2                       Domlur S.O   560071  ...   77.6359   12.9611
# 3  Dr. Shivarama Karanth Nagar S.O   560077  ...   77.6293   13.0681
# 4                  Fraser Town S.O   560005  ...   77.6164   13.0005
#
# [5 rows x 5 columns]

# %%
df4['Area Name'] = df4['officename'].str[:-4]
df5=df4.drop(['officename'], axis=1)
df5.head()
# Out:
#    pincode    divisionname  longitude  latitude                    Area Name
# 0   560045  Bangalore East    77.6206   13.0291               Arabic College
# 1   560103  Bangalore East    77.6760   12.9298                    Bellandur
# 2   560071  Bangalore East    77.6359   12.9611                       Domlur
# 3   560077  Bangalore East    77.6293   13.0681  Dr. Shivarama Karanth Nagar
# 4   560005  Bangalore East    77.6164   13.0005                  Fraser Town

# %%
a=df5.pop('pincode')
b=df5.pop('divisionname')
c=df5.pop('longitude')
d=df5.pop('latitude')
df5['Pin Code']=a
df5['Division Name']=b
df5['longitude']=c
df5['latitude']=d
df5.head()
# Out:
#                      Area Name  Pin Code   Division Name  longitude  latitude
# 0               Arabic College    560045  Bangalore East    77.6206   13.0291
# 1                    Bellandur    560103  Bangalore East    77.6760   12.9298
# 2                       Domlur    560071  Bangalore East    77.6359   12.9611
# 3  Dr. Shivarama Karanth Nagar    560077  Bangalore East    77.6293   13.0681
# 4                  Fraser Town    560005  Bangalore East    77.6164   13.0005

# %%
df5.to_csv('BangaloreData.csv')

# %%
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
import json
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors

import folium

# %%
address = 'Bangalore'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} is {}, {}.'.format(address, latitude, longitude))
# Out:
# /usr/local/lib/python3.6/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Bangalore is 12.9791198, 77.5912997.

# %%
Bangalore_map = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, borough, neighborhood in zip(df5['latitude'], df5['longitude'], df5['Division Name'],df5['Area Name'],):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(Bangalore_map)  
    
Bangalore_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'YVBAZ0H0XRAPKNHGDLYBEQDEQA2PKGHRZZTQTHAFPQDNADWV'
CLIENT_SECRET = 'PDFW5HFHMRKMR31AWN0IEJO143EV5FS1QZWLPTVQKVMM1PGY'
VERSION = 20200412

# %%
neighborhood_latitude = df5.loc[0, 'latitude']
neighborhood_longitude = df5.loc[0, 'longitude']

neighborhood_name = df5.loc[0, 'Area Name']

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, neighborhood_latitude, neighborhood_longitude))
# Out:
# Latitude and longitude values of Arabic College are 13.0291, 77.6206.

# %%
LIMIT = 100
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=YVBAZ0H0XRAPKNHGDLYBEQDEQA2PKGHRZZTQTHAFPQDNADWV&client_secret=PDFW5HFHMRKMR31AWN0IEJO143EV5FS1QZWLPTVQKVMM1PGY&v=20200412&ll=13.0291,77.6206&radius=500&limit=100'

# %%
import requests

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e932af5618f43001bda7372'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50595659e4b04e53f64976c3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '50595659e4b04e53f64976c3',
#        'location': {'address': 'Govinthapur',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'country': 'India',
#         'crossStreet': 'Nagawara',
#         'distance': 267,
#         'formattedAddress': ['Govinthapur (Nagawara)',
#          'Bangalore 560045',
# ...

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues)

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                 name         categories        lat        lng
# 0           Tea Shop        Coffee Shop  13.031503  77.620736
# 1  New Krishna Sagar  Indian Restaurant  13.026125  77.622722

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 2 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Area Name', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
bangalore_venues = getNearbyVenues(names=df5['Area Name'],
                                   latitudes=df5['latitude'],
                                   longitudes=df5['longitude']
                                  )
# Out:
# Arabic College
# Bellandur
# Domlur
# Dr. Shivarama Karanth Nagar
# Fraser Town
# G.K.V.K.
# H.A.L II Stage
# HighCourt
# Jeevanbhimanagar
# Kothanur
# Mahatma Gandhi Road
# Marathahalli Colony
# NAL
# New Thippasandra
# Sadashivanagar
# Sahakaranagar P.O
# Vimanapura
# Yelahanka
# Yelahanka Satellite Town
# Bangalore G.P
# Ashoknagar S.O (Bangal
# B Sk II Stage
# Bannerghatta Road
# Basavanagudi
# Bommanahalli S.O (Bangal
# Bommasandra Industrial Estate
# Carmelram
# Chandapura
# Dharmaram College
# Electronics City
# Gottigere
# HSR Layout
# Hulimavu
# J P Nagar
# Jayanagar
# Jayangar III Block
# JP Nagar III Phase
# Koramangala VI Bk
# Mico Layout
# Padmanabhnagar
# St. John's Medical College
# Gayathrinagar
# Jalahalli East
# Jalahalli
# Mahalakshmipuram Layout
# Malleswaram
# Malleswaram West
# Mathikere
# Msrit
# Palace Guttahalli
# Rajajinagar
# Rajajinagar IVth Block
# Swimming Pool Extn
# Vidyaranyapura
# Vyalikaval Extn
# Yeswanthpura

# %%
print(bangalore_venues.shape)
bangalore_venues.head()
# Out:
# (843, 7)
#         Area Name  Neighborhood Latitude  ...  Venue Longitude        Venue Category
# 0  Arabic College                13.0291  ...        77.620736           Coffee Shop
# 1  Arabic College                13.0291  ...        77.622722     Indian Restaurant
# 2       Bellandur                12.9298  ...        77.679679          Soccer Field
# 3       Bellandur                12.9298  ...        77.675349  Fast Food Restaurant
# 4       Bellandur                12.9298  ...        77.675688  Fast Food Restaurant
#
# [5 rows x 7 columns]

# %%
bangalore_venues.groupby('Area Name').count()
# Out:
#                                Neighborhood Latitude  ...  Venue Category
# Area Name                                             ...
# Arabic College                                     2  ...               2
# Ashoknagar S.O (Bangal                            10  ...              10
# B Sk II Stage                                      4  ...               4
# Bangalore G.P                                     13  ...              13
# Bannerghatta Road                                  7  ...               7
# Basavanagudi                                      25  ...              25
# Bellandur                                         17  ...              17
# Bommanahalli S.O (Bangal                           7  ...               7
# Bommasandra Industrial Estate                      5  ...               5
# Carmelram                                          4  ...               4
# Chandapura                                         3  ...               3
# ...

# %%
print('There are {} uniques categories.'.format(len(bangalore_venues['Venue Category'].unique())))
# Out:
# There are 150 uniques categories.

# %%
# one hot encoding
bangalore_onehot = pd.get_dummies(bangalore_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
bangalore_onehot['Area Name'] = bangalore_venues['Area Name'] 

# move neighborhood column to the first column
fixed_columns = [bangalore_onehot.columns[-1]] + list(bangalore_onehot.columns[:-1])
bangalore_onehot = bangalore_onehot[fixed_columns]

bangalore_onehot.head()
# Out:
#         Area Name  ATM  ...  Vietnamese Restaurant  Women's Store
# 0  Arabic College    0  ...                      0              0
# 1  Arabic College    0  ...                      0              0
# 2       Bellandur    0  ...                      0              0
# 3       Bellandur    0  ...                      0              0
# 4       Bellandur    0  ...                      0              0
#
# [5 rows x 151 columns]

# %%
bangalore_onehot.shape
# Out:
# (843, 151)

# %%
bangalore_grouped = bangalore_onehot.groupby('Area Name').mean().reset_index()
bangalore_grouped
# Out:
#                         Area Name   ATM  ...  Vietnamese Restaurant  Women's Store
# 0                  Arabic College  0.00  ...               0.000000       0.000000
# 1          Ashoknagar S.O (Bangal  0.00  ...               0.000000       0.000000
# 2                   B Sk II Stage  0.00  ...               0.000000       0.000000
# 3                   Bangalore G.P  0.00  ...               0.000000       0.000000
# 4               Bannerghatta Road  0.00  ...               0.000000       0.000000
# 5                    Basavanagudi  0.00  ...               0.000000       0.000000
# 6                       Bellandur  0.00  ...               0.000000       0.000000
# 7        Bommanahalli S.O (Bangal  0.00  ...               0.000000       0.000000
# 8   Bommasandra Industrial Estate  0.00  ...               0.000000       0.000000
# 9                       Carmelram  0.00  ...               0.000000       0.000000
# ...

# %%
bangalore_grouped.shape
# Out:
# (56, 151)

# %%
num_top_venues = 5

for area in bangalore_grouped['Area Name']:
    print("----"+area+"----")
    temp = bangalore_grouped[bangalore_grouped['Area Name'] == area].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Arabic College----
#                  venue  freq
# 0          Coffee Shop   0.5
# 1    Indian Restaurant   0.5
# 2  Indie Movie Theater   0.0
# 3         Intersection   0.0
# 4            Multiplex   0.0
#
#
# ----Ashoknagar S.O (Bangal----
#                  venue  freq
# 0    Indian Restaurant   0.3
# 1    Convenience Store   0.1
# 2            Juice Bar   0.1
# 3  Szechuan Restaurant   0.1
# 4                 Park   0.1
#
#
# ----B Sk II Stage----
#                    venue  freq
# 0         Ice Cream Shop  0.50
# 1   Fast Food Restaurant  0.25
# 2            Pizza Place  0.25
# 3     Persian Restaurant  0.00
# 4  Performing Arts Venue  0.00
#
#
# ----Bangalore G.P----
#                 venue  freq
# 0   Indian Restaurant  0.23
# 1               Hotel  0.23
# 2                Café  0.15
# 3  Chinese Restaurant  0.08
# 4    Capitol Building  0.08
#
#
# ----Bannerghatta Road----
#                venue  freq
# 0               Café  0.29
# 1  Indian Restaurant  0.14
# ...

# %%
import numpy as np

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Area Name']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Area Name'] = bangalore_grouped['Area Name']

for ind in np.arange(bangalore_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(bangalore_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                 Area Name  ... 10th Most Common Venue
# 0          Arabic College  ...                  Diner
# 1  Ashoknagar S.O (Bangal  ...         Cosmetics Shop
# 2           B Sk II Stage  ...                  Diner
# 3           Bangalore G.P  ...           Gourmet Shop
# 4       Bannerghatta Road  ...                Dog Run
#
# [5 rows x 11 columns]

# %%
kclusters = 5

bangalore_grouped_clustering = bangalore_grouped.drop('Area Name', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(bangalore_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 3, 0, 1, 1, 3, 1, 3, 1, 1], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

bangalore_merged = df5

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
bangalore_merged = bangalore_merged.join(neighborhoods_venues_sorted.set_index('Area Name'), on='Area Name')

bangalore_merged.head() # check the last columns!
# Out:
#                      Area Name  ...  10th Most Common Venue
# 0               Arabic College  ...                   Diner
# 1                    Bellandur  ...      Athletics & Sports
# 2                       Domlur  ...                   Diner
# 3  Dr. Shivarama Karanth Nagar  ...            Dessert Shop
# 4                  Fraser Town  ...             Coffee Shop
#
# [5 rows x 16 columns]

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(bangalore_merged['latitude'], bangalore_merged['longitude'], bangalore_merged['Area Name'], bangalore_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bangalore_merged.loc[bangalore_merged['Cluster Labels'] == 0, bangalore_merged.columns[[1] + list(range(5, bangalore_merged.shape[1]))]]
# Out:
#     Pin Code  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 21    560070               0  ...               Dog Run                  Diner
# 41    560021               0  ...            Donut Shop                Dog Run
#
# [2 rows x 12 columns]

# %%
bangalore_merged.loc[bangalore_merged['Cluster Labels'] == 1, bangalore_merged.columns[[1] + list(range(5, bangalore_merged.shape[1]))]]
# Out:
#     Pin Code  ...       10th Most Common Venue
# 1     560103  ...           Athletics & Sports
# 3     560077  ...                 Dessert Shop
# 5     560065  ...                      Dog Run
# 6     560008  ...                  Coffee Shop
# 7     560001  ...                   Donut Shop
# 9     560077  ...                   Donut Shop
# 10    560001  ...               Sandwich Place
# 11    560037  ...                        Diner
# 12    560017  ...                         Pool
# 14    560080  ...             Department Store
# 15    560092  ...           Italian Restaurant
# 16    560017  ...                   Donut Shop
# 17    560064  ...                   Donut Shop
# 19    560001  ...                 Gourmet Shop
# 22    560076  ...                      Dog Run
# 25    560099  ...          Dumpling Restaurant
# 26    560035  ...                      Dog Run
# 28    560029  ...          Dumpling Restaurant
# 29    560100  ...            Electronics Store
# ...

# %%
bangalore_merged.loc[bangalore_merged['Cluster Labels'] == 2, bangalore_merged.columns[[1] + list(range(5, bangalore_merged.shape[1]))]]
# Out:
#     Pin Code  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 18    560064               2  ...               Dog Run     Dim Sum Restaurant
#
# [1 rows x 12 columns]

# %%
bangalore_merged.loc[bangalore_merged['Cluster Labels'] == 3, bangalore_merged.columns[[1] + list(range(5, bangalore_merged.shape[1]))]]
# Out:
#     Pin Code  ...       10th Most Common Venue
# 0     560045  ...                        Diner
# 2     560071  ...                        Diner
# 4     560005  ...                  Coffee Shop
# 8     560075  ...  Eastern European Restaurant
# 13    560075  ...                   Donut Shop
# 20    560050  ...               Cosmetics Shop
# 23    560004  ...                 Dessert Shop
# 24    560068  ...                   Donut Shop
# 27    560081  ...                      Dog Run
# 30    560083  ...         Fast Food Restaurant
# 33    560078  ...                  Bus Station
# 35    560011  ...                      Brewery
# 36    560078  ...                    Multiplex
# 37    560095  ...             Department Store
# 39    560070  ...          Dumpling Restaurant
# 48    560054  ...                      Dog Run
# 49    560003  ...  Eastern European Restaurant
# 51    560010  ...                      Dog Run
# 52    560003  ...                  Pizza Place
#
# ...

# %%
bangalore_merged.loc[bangalore_merged['Cluster Labels'] == 4, bangalore_merged.columns[[1] + list(range(5, bangalore_merged.shape[1]))]]
# Out:
#     Pin Code  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 42    560014               4  ...               Dog Run     Dim Sum Restaurant
#
# [1 rows x 12 columns]
